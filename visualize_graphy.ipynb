# %%
import json
import networkx as nx
from pyvis.network import Network

# %%
graph_data = json.load(open("attribution_graph.json"))
all_nodes = graph_data["nodes"]
all_edges = graph_data["edges"]

# %%
# count how many unique nodes there are that have edges
unique_nodes = set()
for edge in all_edges:
    unique_nodes.add(edge["source"]["id"])
    unique_nodes.add(edge["target"]["id"])

print(len(unique_nodes))
# Out:
# 299

# %%
print(len(all_edges))
# Out:
# 389

# %%
# find a input node in all_nodes
input_node = next((node for node in all_nodes if node["node_type"] == "InputNode"), None)
print(input_node)
# Out:
# {'id': 'input_0', 'layer_index': 0, 'token_position': 0, 'token_str': 'When', 'node_type': 'InputNode'}

# %%
G = nx.DiGraph()
for edge in all_edges:
    source = edge["source"]
    target = edge["target"]
    weight = edge["weight"]
    #if weight > 0.01:
    G.add_edge(source["id"], target["id"], weight=weight)
    if target["id"] in G.nodes:
        #G.add_node(target["id"], **target)
        G.nodes[target["id"]].update(**target)
    if source["id"] in G.nodes:
        #G.add_node(source["id"], **source)
        G.nodes[source["id"]].update(**source)

# %%
# Create a PyVis network
nt = Network(notebook=True, height='750px', width='100%', heading='Attribution Graph')
nt.options.physics.enabled = False
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %%
X_SCALE = 500  # Pixels per token position
Y_SCALE = 100  # Pixels per layer index
Y_OFFSET = 50 # Optional offset to push graph down slightly
position_counters = {}
for node_id, node_attrs in G.nodes(data=True):
    # Determine position based on node attributes
    x_pos = None
    y_pos = None
    print(node_attrs)
    if 'token_position' in node_attrs and node_attrs['token_position'] is not None:
         # Use token_position for x, scaled
        x_pos = node_attrs['token_position'] * X_SCALE 
        if node_attrs['token_position'] not in position_counters:
            position_counters[node_attrs['token_position']] = {}
        if node_attrs['layer_index'] not in position_counters[node_attrs['token_position']]:
            position_counters[node_attrs['token_position']][node_attrs['layer_index']] = 0
        position_counters[node_attrs['token_position']][node_attrs['layer_index']] += 1
    if 'feature_index' in node_attrs:
        x_pos += position_counters[node_attrs['token_position']][node_attrs['layer_index']]/10 * X_SCALE 

    if 'layer_index' in node_attrs and node_attrs['layer_index'] is not None:
         # Use layer_index for y, scaled and potentially inverted
         # Assuming layer 0 at top, higher layers go down
        y_pos = node_attrs['layer_index'] * Y_SCALE + Y_OFFSET
        # If you want layer 0 at the bottom, invert:
        # y_pos = (MAX_LAYER_INDEX - node_attrs['layer_index']) * Y_SCALE + Y_OFFSET
        # (You'd need to determine MAX_LAYER_INDEX first)
    print(x_pos, y_pos)
    # Add the node to Pyvis network with calculated position
    # Also add other attributes like title for hover info
    #title_str = f"ID: {node_id}<br>" + "<br>".join(f"{k}: {v}" for k, v in node_attrs.items())
    title_str = f"ID: {node_id}"
    # Check if positions are valid before adding
    if "input" in node_id or "output" in node_id:
        label = node_attrs.get('token_str', node_id)
        color = "red"
    elif "skip" or "error":
        label = node_id
        color = "green"
    else:
        color = "blue"
        label = node_id
    if x_pos is not None and y_pos is not None:
        nt.add_node(node_id, label=label, title=title_str, x=x_pos, y=y_pos, physics=False,color=color)
    else:
        # Add node without fixed position if attributes are missing (it might float)
        nt.add_node(node_id, label=label, title=title_str, physics=True,color=color) # Allow physics for nodes without position


# --- Add Edges ---
# Add edges from the NetworkX graph G
# Pyvis automatically connects nodes added above
for source, target, edge_attrs in G.edges(data=True):
    print(edge_attrs)
    weight = edge_attrs.get('weight')
    # You can customize edge appearance based on weight, etc.
    title_str = f"Weight: {weight:.4f}" if weight is not None else "No weight"
    nt.add_edge(source, target, value=weight, title=title_str)
# Out:
# {'id': 'intermediate_3_1_27883', 'layer_index': 1, 'token_position': 3, 'feature_index': 27883.0, 'activation': 0.3965, 'node_type': 'IntermediateNode'}
# 1550.0 150
# {'id': 'intermediate_3_23_23237', 'layer_index': 23, 'token_position': 3, 'feature_index': 23237.0, 'activation': 0.0918, 'node_type': 'IntermediateNode'}
# 1550.0 2350
# {'id': 'intermediate_3_2_27759', 'layer_index': 2, 'token_position': 3, 'feature_index': 27759.0, 'activation': 0.1777, 'node_type': 'IntermediateNode'}
# 1550.0 250
# {'id': 'intermediate_3_23_69355', 'layer_index': 23, 'token_position': 3, 'feature_index': 69355.0, 'activation': 0.1289, 'node_type': 'IntermediateNode'}
# 1600.0 2350
# {'id': 'intermediate_3_2_46883', 'layer_index': 2, 'token_position': 3, 'feature_index': 46883.0, 'activation': 0.2217, 'node_type': 'IntermediateNode'}
# 1600.0 250
# {'id': 'intermediate_3_23_48774', 'layer_index': 23, 'token_position': 3, 'feature_index': 48774.0, 'activation': 0.1069, 'node_type': 'IntermediateNode'}
# 1650.0 2350
# {'id': 'intermediate_3_2_63870', 'layer_index': 2, 'token_position': 3, 'feature_index': 63870.0, 'activation': 0.4512, 'node_type': 'IntermediateNode'}
# 1650.0 250
# {'id': 'intermediate_3_23_49172', 'layer_index': 23, 'token_position': 3, 'feature_index': 49172.0, 'activation': 0.1846, 'node_type': 'IntermediateNode'}
# 1700.0 2350
# {'id': 'intermediate_3_23_38723', 'layer_index': 23, 'token_position': 3, 'feature_index': 38723.0, 'activation': 0.0723, 'node_type': 'IntermediateNode'}
# 1750.0 2350
# {'id': 'intermediate_3_23_46217', 'layer_index': 23, 'token_position': 3, 'feature_index': 46217.0, 'activation': 0.0903, 'node_type': 'IntermediateNode'}
# 1800.0 2350
# {'id': 'intermediate_13_2_61158', 'layer_index': 2, 'token_position': 13, 'feature_index': 61158.0, 'activation': 0.2539, 'node_type': 'IntermediateNode'}
# 6550.0 250
# {'id': 'output_13_0', 'layer_index': 30, 'token_position': 13, 'token_str': ' Mary', 'probability': 0.78125, 'logit': 7.96875, 'node_type': 'OutputNode'}
# 6500 3050
# {'id': 'intermediate_1_3_601', 'layer_index': 3, 'token_position': 1, 'feature_index': 601.0, 'activation': 0.0645, 'node_type': 'IntermediateNode'}
# 550.0 350
# {'id': 'intermediate_3_23_57692', 'layer_index': 23, 'token_position': 3, 'feature_index': 57692.0, 'activation': 0.1494, 'node_type': 'IntermediateNode'}
# 1850.0 2350
# {'id': 'intermediate_2_3_19774', 'layer_index': 3, 'token_position': 2, 'feature_index': 19774.0, 'activation': 0.0845, 'node_type': 'IntermediateNode'}
# 1050.0 350
# {'id': 'intermediate_2_3_20764', 'layer_index': 3, 'token_position': 2, 'feature_index': 20764.0, 'activation': 0.2041, 'node_type': 'IntermediateNode'}
# 1100.0 350
# {'id': 'intermediate_3_23_30096', 'layer_index': 23, 'token_position': 3, 'feature_index': 30096.0, 'activation': 0.0737, 'node_type': 'IntermediateNode'}
# 1900.0 2350
# {'id': 'intermediate_2_3_27686', 'layer_index': 3, 'token_position': 2, 'feature_index': 27686.0, 'activation': 0.0981, 'node_type': 'IntermediateNode'}
# 1150.0 350
# {'id': 'intermediate_2_3_58604', 'layer_index': 3, 'token_position': 2, 'feature_index': 58604.0, 'activation': 0.4395, 'node_type': 'IntermediateNode'}
# 1200.0 350
# {'id': 'intermediate_2_3_63334', 'layer_index': 3, 'token_position': 2, 'feature_index': 63334.0, 'activation': 0.104, 'node_type': 'IntermediateNode'}
# 1250.0 350
# {'id': 'intermediate_3_3_25175', 'layer_index': 3, 'token_position': 3, 'feature_index': 25175.0, 'activation': 0.2832, 'node_type': 'IntermediateNode'}
# 1550.0 350
# {'id': 'intermediate_3_4_56792', 'layer_index': 4, 'token_position': 3, 'feature_index': 56792.0, 'activation': 0.1289, 'node_type': 'IntermediateNode'}
# 1550.0 450
# {'id': 'intermediate_0_5_38082', 'layer_index': 5, 'token_position': 0, 'feature_index': 38082.0, 'activation': 0.3867, 'node_type': 'IntermediateNode'}
# 50.0 550
# {'id': 'intermediate_1_5_7678', 'layer_index': 5, 'token_position': 1, 'feature_index': 7678.0, 'activation': 0.0322, 'node_type': 'IntermediateNode'}
# 550.0 550
# {'id': 'intermediate_3_5_30444', 'layer_index': 5, 'token_position': 3, 'feature_index': 30444.0, 'activation': 0.0996, 'node_type': 'IntermediateNode'}
# 1550.0 550
# {'id': 'intermediate_3_5_54699', 'layer_index': 5, 'token_position': 3, 'feature_index': 54699.0, 'activation': 0.1553, 'node_type': 'IntermediateNode'}
# 1600.0 550
# {'id': 'intermediate_13_5_19681', 'layer_index': 5, 'token_position': 13, 'feature_index': 19681.0, 'activation': 0.3809, 'node_type': 'IntermediateNode'}
# 6550.0 550
# {'id': 'intermediate_13_5_58432', 'layer_index': 5, 'token_position': 13, 'feature_index': 58432.0, 'activation': 0.1582, 'node_type': 'IntermediateNode'}
# 6600.0 550
# {'id': 'intermediate_13_5_64038', 'layer_index': 5, 'token_position': 13, 'feature_index': 64038.0, 'activation': 0.4453, 'node_type': 'IntermediateNode'}
# 6650.0 550
# {'id': 'intermediate_0_6_4109', 'layer_index': 6, 'token_position': 0, 'feature_index': 4109.0, 'activation': 0.0439, 'node_type': 'IntermediateNode'}
# 50.0 650
# {'id': 'intermediate_0_6_4358', 'layer_index': 6, 'token_position': 0, 'feature_index': 4358.0, 'activation': 0.0491, 'node_type': 'IntermediateNode'}
# 100.0 650
# {'id': 'intermediate_0_6_5604', 'layer_index': 6, 'token_position': 0, 'feature_index': 5604.0, 'activation': 0.0491, 'node_type': 'IntermediateNode'}
# 150.0 650
# {'id': 'intermediate_0_6_8317', 'layer_index': 6, 'token_position': 0, 'feature_index': 8317.0, 'activation': 0.0503, 'node_type': 'IntermediateNode'}
# 200.0 650
# {'id': 'intermediate_0_6_10810', 'layer_index': 6, 'token_position': 0, 'feature_index': 10810.0, 'activation': 0.2373, 'node_type': 'IntermediateNode'}
# 250.0 650
# {'id': 'intermediate_0_6_11860', 'layer_index': 6, 'token_position': 0, 'feature_index': 11860.0, 'activation': 0.124, 'node_type': 'IntermediateNode'}
# 300.0 650
# {'id': 'intermediate_0_6_11910', 'layer_index': 6, 'token_position': 0, 'feature_index': 11910.0, 'activation': 0.0527, 'node_type': 'IntermediateNode'}
# 350.0 650
# {'id': 'intermediate_0_6_19327', 'layer_index': 6, 'token_position': 0, 'feature_index': 19327.0, 'activation': 0.0461, 'node_type': 'IntermediateNode'}
# 400.0 650
# {'id': 'intermediate_0_6_22559', 'layer_index': 6, 'token_position': 0, 'feature_index': 22559.0, 'activation': 0.0547, 'node_type': 'IntermediateNode'}
# 450.0 650
# {'id': 'intermediate_0_6_24455', 'layer_index': 6, 'token_position': 0, 'feature_index': 24455.0, 'activation': 0.0679, 'node_type': 'IntermediateNode'}
# 500.0 650
# {'id': 'intermediate_0_6_26458', 'layer_index': 6, 'token_position': 0, 'feature_index': 26458.0, 'activation': 0.0708, 'node_type': 'IntermediateNode'}
# 550.0 650
# {'id': 'intermediate_0_6_31557', 'layer_index': 6, 'token_position': 0, 'feature_index': 31557.0, 'activation': 0.1455, 'node_type': 'IntermediateNode'}
# 600.0 650
# {'id': 'intermediate_0_6_31690', 'layer_index': 6, 'token_position': 0, 'feature_index': 31690.0, 'activation': 0.291, 'node_type': 'IntermediateNode'}
# 650.0 650
# {'id': 'intermediate_0_6_47394', 'layer_index': 6, 'token_position': 0, 'feature_index': 47394.0, 'activation': 0.0762, 'node_type': 'IntermediateNode'}
# 700.0 650
# {'id': 'intermediate_0_6_48289', 'layer_index': 6, 'token_position': 0, 'feature_index': 48289.0, 'activation': 0.0962, 'node_type': 'IntermediateNode'}
# 750.0 650
# {'id': 'intermediate_0_6_52454', 'layer_index': 6, 'token_position': 0, 'feature_index': 52454.0, 'activation': 0.168, 'node_type': 'IntermediateNode'}
# 800.0 650
# {'id': 'intermediate_0_6_57480', 'layer_index': 6, 'token_position': 0, 'feature_index': 57480.0, 'activation': 0.2559, 'node_type': 'IntermediateNode'}
# 850.0 650
# {'id': 'intermediate_0_6_59981', 'layer_index': 6, 'token_position': 0, 'feature_index': 59981.0, 'activation': 0.04, 'node_type': 'IntermediateNode'}
# 900.0 650
# {'id': 'intermediate_0_6_62169', 'layer_index': 6, 'token_position': 0, 'feature_index': 62169.0, 'activation': 0.0417, 'node_type': 'IntermediateNode'}
# 950.0 650
# {'id': 'intermediate_0_6_66695', 'layer_index': 6, 'token_position': 0, 'feature_index': 66695.0, 'activation': 0.0996, 'node_type': 'IntermediateNode'}
# 1000.0 650
# {'id': 'intermediate_0_6_68964', 'layer_index': 6, 'token_position': 0, 'feature_index': 68964.0, 'activation': 0.0408, 'node_type': 'IntermediateNode'}
# 1050.0 650
# {'id': 'intermediate_0_7_21254', 'layer_index': 7, 'token_position': 0, 'feature_index': 21254.0, 'activation': 0.0854, 'node_type': 'IntermediateNode'}
# 50.0 750
# {'id': 'intermediate_3_7_28360', 'layer_index': 7, 'token_position': 3, 'feature_index': 28360.0, 'activation': 0.1318, 'node_type': 'IntermediateNode'}
# 1550.0 750
# {'id': 'intermediate_13_7_42900', 'layer_index': 7, 'token_position': 13, 'feature_index': 42900.0, 'activation': 0.166, 'node_type': 'IntermediateNode'}
# 6550.0 750
# {'id': 'intermediate_0_8_785', 'layer_index': 8, 'token_position': 0, 'feature_index': 785.0, 'activation': 0.1191, 'node_type': 'IntermediateNode'}
# 50.0 850
# {'id': 'intermediate_3_23_23689', 'layer_index': 23, 'token_position': 3, 'feature_index': 23689.0, 'activation': 0.0991, 'node_type': 'IntermediateNode'}
# 1950.0 2350
# {'id': 'intermediate_0_8_4870', 'layer_index': 8, 'token_position': 0, 'feature_index': 4870.0, 'activation': 0.1348, 'node_type': 'IntermediateNode'}
# 100.0 850
# {'id': 'intermediate_0_8_14012', 'layer_index': 8, 'token_position': 0, 'feature_index': 14012.0, 'activation': 0.3027, 'node_type': 'IntermediateNode'}
# 150.0 850
# {'id': 'intermediate_0_8_14092', 'layer_index': 8, 'token_position': 0, 'feature_index': 14092.0, 'activation': 0.0601, 'node_type': 'IntermediateNode'}
# 200.0 850
# {'id': 'intermediate_0_8_18803', 'layer_index': 8, 'token_position': 0, 'feature_index': 18803.0, 'activation': 0.1289, 'node_type': 'IntermediateNode'}
# 250.0 850
# {'id': 'intermediate_0_8_21287', 'layer_index': 8, 'token_position': 0, 'feature_index': 21287.0, 'activation': 0.1406, 'node_type': 'IntermediateNode'}
# 300.0 850
# {'id': 'intermediate_0_8_22110', 'layer_index': 8, 'token_position': 0, 'feature_index': 22110.0, 'activation': 0.1328, 'node_type': 'IntermediateNode'}
# 350.0 850
# {'id': 'intermediate_0_8_23584', 'layer_index': 8, 'token_position': 0, 'feature_index': 23584.0, 'activation': 0.2793, 'node_type': 'IntermediateNode'}
# 400.0 850
# {'id': 'intermediate_0_8_32128', 'layer_index': 8, 'token_position': 0, 'feature_index': 32128.0, 'activation': 0.2148, 'node_type': 'IntermediateNode'}
# 450.0 850
# {'id': 'intermediate_0_8_32920', 'layer_index': 8, 'token_position': 0, 'feature_index': 32920.0, 'activation': 0.0742, 'node_type': 'IntermediateNode'}
# 500.0 850
# {'id': 'intermediate_0_8_34219', 'layer_index': 8, 'token_position': 0, 'feature_index': 34219.0, 'activation': 0.1099, 'node_type': 'IntermediateNode'}
# 550.0 850
# {'id': 'intermediate_0_8_43899', 'layer_index': 8, 'token_position': 0, 'feature_index': 43899.0, 'activation': 0.4023, 'node_type': 'IntermediateNode'}
# 600.0 850
# {'id': 'intermediate_0_8_48913', 'layer_index': 8, 'token_position': 0, 'feature_index': 48913.0, 'activation': 0.332, 'node_type': 'IntermediateNode'}
# 650.0 850
# {'id': 'intermediate_0_8_55051', 'layer_index': 8, 'token_position': 0, 'feature_index': 55051.0, 'activation': 0.3066, 'node_type': 'IntermediateNode'}
# 700.0 850
# {'id': 'intermediate_0_8_55364', 'layer_index': 8, 'token_position': 0, 'feature_index': 55364.0, 'activation': 0.0747, 'node_type': 'IntermediateNode'}
# 750.0 850
# {'id': 'intermediate_0_8_61325', 'layer_index': 8, 'token_position': 0, 'feature_index': 61325.0, 'activation': 0.3379, 'node_type': 'IntermediateNode'}
# 800.0 850
# {'id': 'intermediate_0_8_61529', 'layer_index': 8, 'token_position': 0, 'feature_index': 61529.0, 'activation': 0.167, 'node_type': 'IntermediateNode'}
# 850.0 850
# {'id': 'intermediate_0_8_66630', 'layer_index': 8, 'token_position': 0, 'feature_index': 66630.0, 'activation': 0.1543, 'node_type': 'IntermediateNode'}
# 900.0 850
# {'id': 'intermediate_10_8_47501', 'layer_index': 8, 'token_position': 10, 'feature_index': 47501.0, 'activation': 0.0422, 'node_type': 'IntermediateNode'}
# 5050.0 850
# {'id': 'intermediate_1_9_1647', 'layer_index': 9, 'token_position': 1, 'feature_index': 1647.0, 'activation': 0.5195, 'node_type': 'IntermediateNode'}
# 550.0 950
# {'id': 'intermediate_1_9_31867', 'layer_index': 9, 'token_position': 1, 'feature_index': 31867.0, 'activation': 0.1025, 'node_type': 'IntermediateNode'}
# 600.0 950
# {'id': 'intermediate_3_9_1647', 'layer_index': 9, 'token_position': 3, 'feature_index': 1647.0, 'activation': 0.1553, 'node_type': 'IntermediateNode'}
# 1550.0 950
# {'id': 'intermediate_2_10_3077', 'layer_index': 10, 'token_position': 2, 'feature_index': 3077.0, 'activation': 0.05, 'node_type': 'IntermediateNode'}
# 1050.0 1050
# {'id': 'intermediate_2_10_9178', 'layer_index': 10, 'token_position': 2, 'feature_index': 9178.0, 'activation': 0.0957, 'node_type': 'IntermediateNode'}
# 1100.0 1050
# {'id': 'intermediate_2_10_11439', 'layer_index': 10, 'token_position': 2, 'feature_index': 11439.0, 'activation': 0.103, 'node_type': 'IntermediateNode'}
# 1150.0 1050
# {'id': 'intermediate_2_10_17686', 'layer_index': 10, 'token_position': 2, 'feature_index': 17686.0, 'activation': 0.0679, 'node_type': 'IntermediateNode'}
# 1200.0 1050
# {'id': 'intermediate_2_10_19491', 'layer_index': 10, 'token_position': 2, 'feature_index': 19491.0, 'activation': 0.1826, 'node_type': 'IntermediateNode'}
# 1250.0 1050
# {'id': 'intermediate_2_10_24298', 'layer_index': 10, 'token_position': 2, 'feature_index': 24298.0, 'activation': 0.0442, 'node_type': 'IntermediateNode'}
# 1300.0 1050
# {'id': 'intermediate_2_10_28950', 'layer_index': 10, 'token_position': 2, 'feature_index': 28950.0, 'activation': 0.0483, 'node_type': 'IntermediateNode'}
# 1350.0 1050
# {'id': 'intermediate_2_10_32226', 'layer_index': 10, 'token_position': 2, 'feature_index': 32226.0, 'activation': 0.0483, 'node_type': 'IntermediateNode'}
# 1400.0 1050
# {'id': 'intermediate_2_10_36015', 'layer_index': 10, 'token_position': 2, 'feature_index': 36015.0, 'activation': 0.1118, 'node_type': 'IntermediateNode'}
# 1450.0 1050
# {'id': 'intermediate_2_10_36395', 'layer_index': 10, 'token_position': 2, 'feature_index': 36395.0, 'activation': 0.2617, 'node_type': 'IntermediateNode'}
# 1500.0 1050
# {'id': 'intermediate_2_10_39603', 'layer_index': 10, 'token_position': 2, 'feature_index': 39603.0, 'activation': 0.0598, 'node_type': 'IntermediateNode'}
# 1550.0 1050
# {'id': 'intermediate_2_10_45155', 'layer_index': 10, 'token_position': 2, 'feature_index': 45155.0, 'activation': 0.1201, 'node_type': 'IntermediateNode'}
# 1600.0 1050
# {'id': 'intermediate_2_10_45761', 'layer_index': 10, 'token_position': 2, 'feature_index': 45761.0, 'activation': 0.0942, 'node_type': 'IntermediateNode'}
# 1650.0 1050
# {'id': 'intermediate_2_10_50345', 'layer_index': 10, 'token_position': 2, 'feature_index': 50345.0, 'activation': 0.1934, 'node_type': 'IntermediateNode'}
# 1700.0 1050
# {'id': 'intermediate_2_10_54454', 'layer_index': 10, 'token_position': 2, 'feature_index': 54454.0, 'activation': 0.1162, 'node_type': 'IntermediateNode'}
# 1750.0 1050
# {'id': 'intermediate_2_10_54869', 'layer_index': 10, 'token_position': 2, 'feature_index': 54869.0, 'activation': 0.0505, 'node_type': 'IntermediateNode'}
# 1800.0 1050
# {'id': 'intermediate_2_10_56666', 'layer_index': 10, 'token_position': 2, 'feature_index': 56666.0, 'activation': 0.0544, 'node_type': 'IntermediateNode'}
# 1850.0 1050
# {'id': 'intermediate_2_10_67320', 'layer_index': 10, 'token_position': 2, 'feature_index': 67320.0, 'activation': 0.0503, 'node_type': 'IntermediateNode'}
# 1900.0 1050
# {'id': 'intermediate_2_10_70605', 'layer_index': 10, 'token_position': 2, 'feature_index': 70605.0, 'activation': 0.1001, 'node_type': 'IntermediateNode'}
# 1950.0 1050
# {'id': 'intermediate_2_10_72382', 'layer_index': 10, 'token_position': 2, 'feature_index': 72382.0, 'activation': 0.054, 'node_type': 'IntermediateNode'}
# 2000.0 1050
# {'id': 'intermediate_3_10_68953', 'layer_index': 10, 'token_position': 3, 'feature_index': 68953.0, 'activation': 0.5547, 'node_type': 'IntermediateNode'}
# 1550.0 1050
# {'id': 'intermediate_2_11_62679', 'layer_index': 11, 'token_position': 2, 'feature_index': 62679.0, 'activation': 0.4707, 'node_type': 'IntermediateNode'}
# 1050.0 1150
# {'id': 'intermediate_3_11_8643', 'layer_index': 11, 'token_position': 3, 'feature_index': 8643.0, 'activation': 0.2207, 'node_type': 'IntermediateNode'}
# 1550.0 1150
# {'id': 'intermediate_3_11_26173', 'layer_index': 11, 'token_position': 3, 'feature_index': 26173.0, 'activation': 0.0723, 'node_type': 'IntermediateNode'}
# 1600.0 1150
# {'id': 'intermediate_3_11_46501', 'layer_index': 11, 'token_position': 3, 'feature_index': 46501.0, 'activation': 0.2393, 'node_type': 'IntermediateNode'}
# 1650.0 1150
# {'id': 'intermediate_3_11_48847', 'layer_index': 11, 'token_position': 3, 'feature_index': 48847.0, 'activation': 0.1416, 'node_type': 'IntermediateNode'}
# 1700.0 1150
# {'id': 'intermediate_3_11_55847', 'layer_index': 11, 'token_position': 3, 'feature_index': 55847.0, 'activation': 0.1514, 'node_type': 'IntermediateNode'}
# 1750.0 1150
# {'id': 'intermediate_1_12_65061', 'layer_index': 12, 'token_position': 1, 'feature_index': 65061.0, 'activation': 0.1738, 'node_type': 'IntermediateNode'}
# 550.0 1250
# {'id': 'intermediate_3_12_14070', 'layer_index': 12, 'token_position': 3, 'feature_index': 14070.0, 'activation': 0.4258, 'node_type': 'IntermediateNode'}
# 1550.0 1250
# {'id': 'intermediate_3_12_39061', 'layer_index': 12, 'token_position': 3, 'feature_index': 39061.0, 'activation': 0.252, 'node_type': 'IntermediateNode'}
# 1600.0 1250
# {'id': 'intermediate_3_12_67743', 'layer_index': 12, 'token_position': 3, 'feature_index': 67743.0, 'activation': 0.1416, 'node_type': 'IntermediateNode'}
# 1650.0 1250
# {'id': 'intermediate_3_13_1364', 'layer_index': 13, 'token_position': 3, 'feature_index': 1364.0, 'activation': 0.1494, 'node_type': 'IntermediateNode'}
# 1550.0 1350
# {'id': 'intermediate_3_13_9907', 'layer_index': 13, 'token_position': 3, 'feature_index': 9907.0, 'activation': 0.2871, 'node_type': 'IntermediateNode'}
# 1600.0 1350
# {'id': 'intermediate_3_13_58750', 'layer_index': 13, 'token_position': 3, 'feature_index': 58750.0, 'activation': 0.2324, 'node_type': 'IntermediateNode'}
# 1650.0 1350
# {'id': 'intermediate_3_13_59455', 'layer_index': 13, 'token_position': 3, 'feature_index': 59455.0, 'activation': 0.1533, 'node_type': 'IntermediateNode'}
# 1700.0 1350
# {'id': 'intermediate_13_13_53026', 'layer_index': 13, 'token_position': 13, 'feature_index': 53026.0, 'activation': 0.1797, 'node_type': 'IntermediateNode'}
# 6550.0 1350
# {'id': 'intermediate_0_14_50304', 'layer_index': 14, 'token_position': 0, 'feature_index': 50304.0, 'activation': 0.1797, 'node_type': 'IntermediateNode'}
# 50.0 1450
# {'id': 'intermediate_0_14_52928', 'layer_index': 14, 'token_position': 0, 'feature_index': 52928.0, 'activation': 0.3379, 'node_type': 'IntermediateNode'}
# 100.0 1450
# {'id': 'intermediate_0_14_53649', 'layer_index': 14, 'token_position': 0, 'feature_index': 53649.0, 'activation': 0.1807, 'node_type': 'IntermediateNode'}
# 150.0 1450
# {'id': 'intermediate_0_14_69669', 'layer_index': 14, 'token_position': 0, 'feature_index': 69669.0, 'activation': 0.1768, 'node_type': 'IntermediateNode'}
# 200.0 1450
# {'id': 'intermediate_3_14_483', 'layer_index': 14, 'token_position': 3, 'feature_index': 483.0, 'activation': 0.2695, 'node_type': 'IntermediateNode'}
# 1550.0 1450
# {'id': 'intermediate_3_14_3745', 'layer_index': 14, 'token_position': 3, 'feature_index': 3745.0, 'activation': 0.25, 'node_type': 'IntermediateNode'}
# 1600.0 1450
# {'id': 'intermediate_3_14_13701', 'layer_index': 14, 'token_position': 3, 'feature_index': 13701.0, 'activation': 0.1387, 'node_type': 'IntermediateNode'}
# 1650.0 1450
# {'id': 'intermediate_3_14_17072', 'layer_index': 14, 'token_position': 3, 'feature_index': 17072.0, 'activation': 0.1084, 'node_type': 'IntermediateNode'}
# 1700.0 1450
# {'id': 'intermediate_3_14_39227', 'layer_index': 14, 'token_position': 3, 'feature_index': 39227.0, 'activation': 0.1387, 'node_type': 'IntermediateNode'}
# 1750.0 1450
# {'id': 'intermediate_3_14_40757', 'layer_index': 14, 'token_position': 3, 'feature_index': 40757.0, 'activation': 0.3711, 'node_type': 'IntermediateNode'}
# 1800.0 1450
# {'id': 'intermediate_3_14_49261', 'layer_index': 14, 'token_position': 3, 'feature_index': 49261.0, 'activation': 0.2314, 'node_type': 'IntermediateNode'}
# 1850.0 1450
# {'id': 'intermediate_3_14_58382', 'layer_index': 14, 'token_position': 3, 'feature_index': 58382.0, 'activation': 0.1182, 'node_type': 'IntermediateNode'}
# 1900.0 1450
# {'id': 'intermediate_3_14_62461', 'layer_index': 14, 'token_position': 3, 'feature_index': 62461.0, 'activation': 0.3516, 'node_type': 'IntermediateNode'}
# 1950.0 1450
# {'id': 'intermediate_0_15_4921', 'layer_index': 15, 'token_position': 0, 'feature_index': 4921.0, 'activation': 0.373, 'node_type': 'IntermediateNode'}
# 50.0 1550
# {'id': 'intermediate_0_15_10316', 'layer_index': 15, 'token_position': 0, 'feature_index': 10316.0, 'activation': 0.3125, 'node_type': 'IntermediateNode'}
# 100.0 1550
# {'id': 'intermediate_0_15_10643', 'layer_index': 15, 'token_position': 0, 'feature_index': 10643.0, 'activation': 0.125, 'node_type': 'IntermediateNode'}
# 150.0 1550
# {'id': 'intermediate_0_15_14064', 'layer_index': 15, 'token_position': 0, 'feature_index': 14064.0, 'activation': 0.2129, 'node_type': 'IntermediateNode'}
# 200.0 1550
# {'id': 'intermediate_0_15_17272', 'layer_index': 15, 'token_position': 0, 'feature_index': 17272.0, 'activation': 0.1245, 'node_type': 'IntermediateNode'}
# 250.0 1550
# {'id': 'intermediate_0_15_18621', 'layer_index': 15, 'token_position': 0, 'feature_index': 18621.0, 'activation': 0.126, 'node_type': 'IntermediateNode'}
# 300.0 1550
# {'id': 'intermediate_0_15_18676', 'layer_index': 15, 'token_position': 0, 'feature_index': 18676.0, 'activation': 0.1245, 'node_type': 'IntermediateNode'}
# 350.0 1550
# {'id': 'intermediate_0_15_22017', 'layer_index': 15, 'token_position': 0, 'feature_index': 22017.0, 'activation': 0.4004, 'node_type': 'IntermediateNode'}
# 400.0 1550
# {'id': 'intermediate_0_15_24224', 'layer_index': 15, 'token_position': 0, 'feature_index': 24224.0, 'activation': 0.3047, 'node_type': 'IntermediateNode'}
# 450.0 1550
# {'id': 'intermediate_0_15_25989', 'layer_index': 15, 'token_position': 0, 'feature_index': 25989.0, 'activation': 0.124, 'node_type': 'IntermediateNode'}
# 500.0 1550
# {'id': 'intermediate_0_15_26061', 'layer_index': 15, 'token_position': 0, 'feature_index': 26061.0, 'activation': 0.1572, 'node_type': 'IntermediateNode'}
# 550.0 1550
# {'id': 'intermediate_0_15_34106', 'layer_index': 15, 'token_position': 0, 'feature_index': 34106.0, 'activation': 0.124, 'node_type': 'IntermediateNode'}
# 600.0 1550
# {'id': 'intermediate_0_15_40381', 'layer_index': 15, 'token_position': 0, 'feature_index': 40381.0, 'activation': 0.2773, 'node_type': 'IntermediateNode'}
# 650.0 1550
# {'id': 'intermediate_0_15_45415', 'layer_index': 15, 'token_position': 0, 'feature_index': 45415.0, 'activation': 0.3809, 'node_type': 'IntermediateNode'}
# 700.0 1550
# {'id': 'intermediate_0_15_47638', 'layer_index': 15, 'token_position': 0, 'feature_index': 47638.0, 'activation': 0.2412, 'node_type': 'IntermediateNode'}
# 750.0 1550
# {'id': 'intermediate_0_15_48758', 'layer_index': 15, 'token_position': 0, 'feature_index': 48758.0, 'activation': 0.1719, 'node_type': 'IntermediateNode'}
# 800.0 1550
# {'id': 'intermediate_0_15_49480', 'layer_index': 15, 'token_position': 0, 'feature_index': 49480.0, 'activation': 0.125, 'node_type': 'IntermediateNode'}
# 850.0 1550
# {'id': 'intermediate_0_15_49908', 'layer_index': 15, 'token_position': 0, 'feature_index': 49908.0, 'activation': 0.125, 'node_type': 'IntermediateNode'}
# 900.0 1550
# {'id': 'intermediate_0_15_52441', 'layer_index': 15, 'token_position': 0, 'feature_index': 52441.0, 'activation': 0.1289, 'node_type': 'IntermediateNode'}
# 950.0 1550
# {'id': 'intermediate_0_15_54293', 'layer_index': 15, 'token_position': 0, 'feature_index': 54293.0, 'activation': 0.2598, 'node_type': 'IntermediateNode'}
# 1000.0 1550
# {'id': 'intermediate_0_15_55302', 'layer_index': 15, 'token_position': 0, 'feature_index': 55302.0, 'activation': 0.126, 'node_type': 'IntermediateNode'}
# 1050.0 1550
# {'id': 'intermediate_0_15_70555', 'layer_index': 15, 'token_position': 0, 'feature_index': 70555.0, 'activation': 0.124, 'node_type': 'IntermediateNode'}
# 1100.0 1550
# {'id': 'intermediate_3_15_13115', 'layer_index': 15, 'token_position': 3, 'feature_index': 13115.0, 'activation': 0.2314, 'node_type': 'IntermediateNode'}
# 1550.0 1550
# {'id': 'intermediate_3_15_60339', 'layer_index': 15, 'token_position': 3, 'feature_index': 60339.0, 'activation': 0.1914, 'node_type': 'IntermediateNode'}
# 1600.0 1550
# {'id': 'intermediate_13_15_54694', 'layer_index': 15, 'token_position': 13, 'feature_index': 54694.0, 'activation': 0.7578, 'node_type': 'IntermediateNode'}
# 6550.0 1550
# {'id': 'intermediate_0_16_14804', 'layer_index': 16, 'token_position': 0, 'feature_index': 14804.0, 'activation': 0.5586, 'node_type': 'IntermediateNode'}
# 50.0 1650
# {'id': 'intermediate_0_16_33228', 'layer_index': 16, 'token_position': 0, 'feature_index': 33228.0, 'activation': 0.4199, 'node_type': 'IntermediateNode'}
# 100.0 1650
# {'id': 'intermediate_0_16_50863', 'layer_index': 16, 'token_position': 0, 'feature_index': 50863.0, 'activation': 0.4551, 'node_type': 'IntermediateNode'}
# 150.0 1650
# {'id': 'intermediate_2_16_5748', 'layer_index': 16, 'token_position': 2, 'feature_index': 5748.0, 'activation': 0.3633, 'node_type': 'IntermediateNode'}
# 1050.0 1650
# {'id': 'intermediate_2_16_8746', 'layer_index': 16, 'token_position': 2, 'feature_index': 8746.0, 'activation': 0.168, 'node_type': 'IntermediateNode'}
# 1100.0 1650
# {'id': 'intermediate_2_16_22387', 'layer_index': 16, 'token_position': 2, 'feature_index': 22387.0, 'activation': 0.0981, 'node_type': 'IntermediateNode'}
# 1150.0 1650
# {'id': 'intermediate_2_16_43410', 'layer_index': 16, 'token_position': 2, 'feature_index': 43410.0, 'activation': 0.3281, 'node_type': 'IntermediateNode'}
# 1200.0 1650
# {'id': 'intermediate_3_16_27539', 'layer_index': 16, 'token_position': 3, 'feature_index': 27539.0, 'activation': 0.2119, 'node_type': 'IntermediateNode'}
# 1550.0 1650
# {'id': 'intermediate_3_16_29711', 'layer_index': 16, 'token_position': 3, 'feature_index': 29711.0, 'activation': 0.106, 'node_type': 'IntermediateNode'}
# 1600.0 1650
# {'id': 'intermediate_3_16_71659', 'layer_index': 16, 'token_position': 3, 'feature_index': 71659.0, 'activation': 0.375, 'node_type': 'IntermediateNode'}
# 1650.0 1650
# {'id': 'intermediate_0_17_3834', 'layer_index': 17, 'token_position': 0, 'feature_index': 3834.0, 'activation': 0.4902, 'node_type': 'IntermediateNode'}
# 50.0 1750
# {'id': 'intermediate_0_17_3889', 'layer_index': 17, 'token_position': 0, 'feature_index': 3889.0, 'activation': 0.1719, 'node_type': 'IntermediateNode'}
# 100.0 1750
# {'id': 'intermediate_0_17_5931', 'layer_index': 17, 'token_position': 0, 'feature_index': 5931.0, 'activation': 1.0781, 'node_type': 'IntermediateNode'}
# 150.0 1750
# {'id': 'intermediate_0_17_7538', 'layer_index': 17, 'token_position': 0, 'feature_index': 7538.0, 'activation': 0.6836, 'node_type': 'IntermediateNode'}
# 200.0 1750
# {'id': 'intermediate_0_17_11828', 'layer_index': 17, 'token_position': 0, 'feature_index': 11828.0, 'activation': 0.3125, 'node_type': 'IntermediateNode'}
# 250.0 1750
# {'id': 'intermediate_0_17_14474', 'layer_index': 17, 'token_position': 0, 'feature_index': 14474.0, 'activation': 0.1738, 'node_type': 'IntermediateNode'}
# 300.0 1750
# {'id': 'intermediate_0_17_21513', 'layer_index': 17, 'token_position': 0, 'feature_index': 21513.0, 'activation': 0.875, 'node_type': 'IntermediateNode'}
# 350.0 1750
# {'id': 'intermediate_0_17_23835', 'layer_index': 17, 'token_position': 0, 'feature_index': 23835.0, 'activation': 0.3984, 'node_type': 'IntermediateNode'}
# 400.0 1750
# {'id': 'intermediate_0_17_24309', 'layer_index': 17, 'token_position': 0, 'feature_index': 24309.0, 'activation': 0.4902, 'node_type': 'IntermediateNode'}
# 450.0 1750
# {'id': 'intermediate_0_17_31199', 'layer_index': 17, 'token_position': 0, 'feature_index': 31199.0, 'activation': 0.418, 'node_type': 'IntermediateNode'}
# 500.0 1750
# {'id': 'intermediate_0_17_31263', 'layer_index': 17, 'token_position': 0, 'feature_index': 31263.0, 'activation': 0.6094, 'node_type': 'IntermediateNode'}
# 550.0 1750
# {'id': 'intermediate_0_17_33262', 'layer_index': 17, 'token_position': 0, 'feature_index': 33262.0, 'activation': 0.5195, 'node_type': 'IntermediateNode'}
# 600.0 1750
# {'id': 'intermediate_0_17_34315', 'layer_index': 17, 'token_position': 0, 'feature_index': 34315.0, 'activation': 0.3613, 'node_type': 'IntermediateNode'}
# 650.0 1750
# {'id': 'intermediate_0_17_34578', 'layer_index': 17, 'token_position': 0, 'feature_index': 34578.0, 'activation': 0.3984, 'node_type': 'IntermediateNode'}
# 700.0 1750
# {'id': 'intermediate_0_17_36796', 'layer_index': 17, 'token_position': 0, 'feature_index': 36796.0, 'activation': 0.1758, 'node_type': 'IntermediateNode'}
# 750.0 1750
# {'id': 'intermediate_0_17_53784', 'layer_index': 17, 'token_position': 0, 'feature_index': 53784.0, 'activation': 0.3281, 'node_type': 'IntermediateNode'}
# 800.0 1750
# {'id': 'intermediate_0_17_54293', 'layer_index': 17, 'token_position': 0, 'feature_index': 54293.0, 'activation': 0.377, 'node_type': 'IntermediateNode'}
# 850.0 1750
# {'id': 'intermediate_0_17_54498', 'layer_index': 17, 'token_position': 0, 'feature_index': 54498.0, 'activation': 0.2598, 'node_type': 'IntermediateNode'}
# 900.0 1750
# {'id': 'intermediate_0_17_55163', 'layer_index': 17, 'token_position': 0, 'feature_index': 55163.0, 'activation': 0.1719, 'node_type': 'IntermediateNode'}
# 950.0 1750
# {'id': 'intermediate_0_17_55709', 'layer_index': 17, 'token_position': 0, 'feature_index': 55709.0, 'activation': 0.1719, 'node_type': 'IntermediateNode'}
# 1000.0 1750
# {'id': 'intermediate_0_17_59870', 'layer_index': 17, 'token_position': 0, 'feature_index': 59870.0, 'activation': 0.6406, 'node_type': 'IntermediateNode'}
# 1050.0 1750
# {'id': 'intermediate_0_17_60029', 'layer_index': 17, 'token_position': 0, 'feature_index': 60029.0, 'activation': 0.1719, 'node_type': 'IntermediateNode'}
# 1100.0 1750
# {'id': 'intermediate_0_17_60492', 'layer_index': 17, 'token_position': 0, 'feature_index': 60492.0, 'activation': 0.2334, 'node_type': 'IntermediateNode'}
# 1150.0 1750
# {'id': 'intermediate_0_17_60539', 'layer_index': 17, 'token_position': 0, 'feature_index': 60539.0, 'activation': 0.1719, 'node_type': 'IntermediateNode'}
# 1200.0 1750
# {'id': 'intermediate_0_17_61299', 'layer_index': 17, 'token_position': 0, 'feature_index': 61299.0, 'activation': 0.3789, 'node_type': 'IntermediateNode'}
# 1250.0 1750
# {'id': 'intermediate_0_17_61807', 'layer_index': 17, 'token_position': 0, 'feature_index': 61807.0, 'activation': 0.2539, 'node_type': 'IntermediateNode'}
# 1300.0 1750
# {'id': 'intermediate_0_17_62739', 'layer_index': 17, 'token_position': 0, 'feature_index': 62739.0, 'activation': 0.3086, 'node_type': 'IntermediateNode'}
# 1350.0 1750
# {'id': 'intermediate_0_17_64336', 'layer_index': 17, 'token_position': 0, 'feature_index': 64336.0, 'activation': 0.3652, 'node_type': 'IntermediateNode'}
# 1400.0 1750
# {'id': 'intermediate_0_17_67859', 'layer_index': 17, 'token_position': 0, 'feature_index': 67859.0, 'activation': 0.1719, 'node_type': 'IntermediateNode'}
# 1450.0 1750
# {'id': 'intermediate_0_17_72170', 'layer_index': 17, 'token_position': 0, 'feature_index': 72170.0, 'activation': 0.1729, 'node_type': 'IntermediateNode'}
# 1500.0 1750
# {'id': 'intermediate_0_17_10797', 'layer_index': 17, 'token_position': 0, 'feature_index': 10797.0, 'activation': 0.1709, 'node_type': 'IntermediateNode'}
# 1550.0 1750
# {'id': 'intermediate_0_17_25155', 'layer_index': 17, 'token_position': 0, 'feature_index': 25155.0, 'activation': 0.1709, 'node_type': 'IntermediateNode'}
# 1600.0 1750
# {'id': 'intermediate_0_17_41766', 'layer_index': 17, 'token_position': 0, 'feature_index': 41766.0, 'activation': 0.1709, 'node_type': 'IntermediateNode'}
# 1650.0 1750
# {'id': 'intermediate_0_17_51650', 'layer_index': 17, 'token_position': 0, 'feature_index': 51650.0, 'activation': 0.1709, 'node_type': 'IntermediateNode'}
# 1700.0 1750
# {'id': 'intermediate_0_17_52823', 'layer_index': 17, 'token_position': 0, 'feature_index': 52823.0, 'activation': 0.1709, 'node_type': 'IntermediateNode'}
# 1750.0 1750
# {'id': 'intermediate_0_17_58263', 'layer_index': 17, 'token_position': 0, 'feature_index': 58263.0, 'activation': 0.1709, 'node_type': 'IntermediateNode'}
# 1800.0 1750
# {'id': 'intermediate_0_17_62371', 'layer_index': 17, 'token_position': 0, 'feature_index': 62371.0, 'activation': 0.1709, 'node_type': 'IntermediateNode'}
# 1850.0 1750
# {'id': 'intermediate_2_17_23593', 'layer_index': 17, 'token_position': 2, 'feature_index': 23593.0, 'activation': 0.1367, 'node_type': 'IntermediateNode'}
# 1050.0 1750
# {'id': 'intermediate_2_17_31250', 'layer_index': 17, 'token_position': 2, 'feature_index': 31250.0, 'activation': 0.103, 'node_type': 'IntermediateNode'}
# 1100.0 1750
# {'id': 'intermediate_2_17_32124', 'layer_index': 17, 'token_position': 2, 'feature_index': 32124.0, 'activation': 0.1543, 'node_type': 'IntermediateNode'}
# 1150.0 1750
# {'id': 'intermediate_2_17_66017', 'layer_index': 17, 'token_position': 2, 'feature_index': 66017.0, 'activation': 0.1309, 'node_type': 'IntermediateNode'}
# 1200.0 1750
# {'id': 'intermediate_2_17_71994', 'layer_index': 17, 'token_position': 2, 'feature_index': 71994.0, 'activation': 0.0835, 'node_type': 'IntermediateNode'}
# 1250.0 1750
# {'id': 'intermediate_3_17_159', 'layer_index': 17, 'token_position': 3, 'feature_index': 159.0, 'activation': 0.1943, 'node_type': 'IntermediateNode'}
# 1550.0 1750
# {'id': 'intermediate_3_17_2019', 'layer_index': 17, 'token_position': 3, 'feature_index': 2019.0, 'activation': 0.3477, 'node_type': 'IntermediateNode'}
# 1600.0 1750
# {'id': 'intermediate_3_17_15342', 'layer_index': 17, 'token_position': 3, 'feature_index': 15342.0, 'activation': 0.1235, 'node_type': 'IntermediateNode'}
# 1650.0 1750
# {'id': 'intermediate_3_17_18604', 'layer_index': 17, 'token_position': 3, 'feature_index': 18604.0, 'activation': 0.332, 'node_type': 'IntermediateNode'}
# 1700.0 1750
# {'id': 'intermediate_3_17_23576', 'layer_index': 17, 'token_position': 3, 'feature_index': 23576.0, 'activation': 0.2129, 'node_type': 'IntermediateNode'}
# 1750.0 1750
# {'id': 'intermediate_3_17_33042', 'layer_index': 17, 'token_position': 3, 'feature_index': 33042.0, 'activation': 0.2656, 'node_type': 'IntermediateNode'}
# 1800.0 1750
# {'id': 'intermediate_3_17_39050', 'layer_index': 17, 'token_position': 3, 'feature_index': 39050.0, 'activation': 0.1348, 'node_type': 'IntermediateNode'}
# 1850.0 1750
# {'id': 'intermediate_3_17_55041', 'layer_index': 17, 'token_position': 3, 'feature_index': 55041.0, 'activation': 0.1011, 'node_type': 'IntermediateNode'}
# 1900.0 1750
# {'id': 'intermediate_3_17_66875', 'layer_index': 17, 'token_position': 3, 'feature_index': 66875.0, 'activation': 0.5078, 'node_type': 'IntermediateNode'}
# 1950.0 1750
# {'id': 'intermediate_3_17_67052', 'layer_index': 17, 'token_position': 3, 'feature_index': 67052.0, 'activation': 0.2305, 'node_type': 'IntermediateNode'}
# 2000.0 1750
# {'id': 'intermediate_3_17_68962', 'layer_index': 17, 'token_position': 3, 'feature_index': 68962.0, 'activation': 0.2051, 'node_type': 'IntermediateNode'}
# 2050.0 1750
# {'id': 'intermediate_3_17_72680', 'layer_index': 17, 'token_position': 3, 'feature_index': 72680.0, 'activation': 0.3203, 'node_type': 'IntermediateNode'}
# 2100.0 1750
# {'id': 'intermediate_3_18_14248', 'layer_index': 18, 'token_position': 3, 'feature_index': 14248.0, 'activation': 0.1719, 'node_type': 'IntermediateNode'}
# 1550.0 1850
# {'id': 'intermediate_3_18_19905', 'layer_index': 18, 'token_position': 3, 'feature_index': 19905.0, 'activation': 0.1797, 'node_type': 'IntermediateNode'}
# 1600.0 1850
# {'id': 'intermediate_3_18_25810', 'layer_index': 18, 'token_position': 3, 'feature_index': 25810.0, 'activation': 0.1235, 'node_type': 'IntermediateNode'}
# 1650.0 1850
# {'id': 'intermediate_3_18_46452', 'layer_index': 18, 'token_position': 3, 'feature_index': 46452.0, 'activation': 0.1582, 'node_type': 'IntermediateNode'}
# 1700.0 1850
# {'id': 'intermediate_3_18_58445', 'layer_index': 18, 'token_position': 3, 'feature_index': 58445.0, 'activation': 0.1631, 'node_type': 'IntermediateNode'}
# 1750.0 1850
# {'id': 'intermediate_3_18_69803', 'layer_index': 18, 'token_position': 3, 'feature_index': 69803.0, 'activation': 0.125, 'node_type': 'IntermediateNode'}
# 1800.0 1850
# {'id': 'intermediate_3_18_71344', 'layer_index': 18, 'token_position': 3, 'feature_index': 71344.0, 'activation': 0.2178, 'node_type': 'IntermediateNode'}
# 1850.0 1850
# {'id': 'intermediate_0_19_20428', 'layer_index': 19, 'token_position': 0, 'feature_index': 20428.0, 'activation': 0.168, 'node_type': 'IntermediateNode'}
# 50.0 1950
# {'id': 'intermediate_0_19_21353', 'layer_index': 19, 'token_position': 0, 'feature_index': 21353.0, 'activation': 0.2734, 'node_type': 'IntermediateNode'}
# 100.0 1950
# {'id': 'intermediate_0_19_38537', 'layer_index': 19, 'token_position': 0, 'feature_index': 38537.0, 'activation': 0.166, 'node_type': 'IntermediateNode'}
# 150.0 1950
# {'id': 'intermediate_0_19_40064', 'layer_index': 19, 'token_position': 0, 'feature_index': 40064.0, 'activation': 0.166, 'node_type': 'IntermediateNode'}
# 200.0 1950
# {'id': 'intermediate_0_19_48668', 'layer_index': 19, 'token_position': 0, 'feature_index': 48668.0, 'activation': 0.167, 'node_type': 'IntermediateNode'}
# 250.0 1950
# {'id': 'intermediate_0_19_62195', 'layer_index': 19, 'token_position': 0, 'feature_index': 62195.0, 'activation': 0.4629, 'node_type': 'IntermediateNode'}
# 300.0 1950
# {'id': 'intermediate_0_19_72912', 'layer_index': 19, 'token_position': 0, 'feature_index': 72912.0, 'activation': 0.3301, 'node_type': 'IntermediateNode'}
# 350.0 1950
# {'id': 'intermediate_1_19_7435', 'layer_index': 19, 'token_position': 1, 'feature_index': 7435.0, 'activation': 0.0618, 'node_type': 'IntermediateNode'}
# 550.0 1950
# {'id': 'intermediate_1_19_20184', 'layer_index': 19, 'token_position': 1, 'feature_index': 20184.0, 'activation': 0.0554, 'node_type': 'IntermediateNode'}
# 600.0 1950
# {'id': 'intermediate_1_19_35399', 'layer_index': 19, 'token_position': 1, 'feature_index': 35399.0, 'activation': 0.0908, 'node_type': 'IntermediateNode'}
# 650.0 1950
# {'id': 'intermediate_1_19_40358', 'layer_index': 19, 'token_position': 1, 'feature_index': 40358.0, 'activation': 0.0552, 'node_type': 'IntermediateNode'}
# 700.0 1950
# {'id': 'intermediate_1_19_51049', 'layer_index': 19, 'token_position': 1, 'feature_index': 51049.0, 'activation': 0.053, 'node_type': 'IntermediateNode'}
# 750.0 1950
# {'id': 'intermediate_1_19_53404', 'layer_index': 19, 'token_position': 1, 'feature_index': 53404.0, 'activation': 0.0593, 'node_type': 'IntermediateNode'}
# 800.0 1950
# {'id': 'intermediate_1_19_60952', 'layer_index': 19, 'token_position': 1, 'feature_index': 60952.0, 'activation': 0.1543, 'node_type': 'IntermediateNode'}
# 850.0 1950
# {'id': 'intermediate_1_19_73528', 'layer_index': 19, 'token_position': 1, 'feature_index': 73528.0, 'activation': 0.1699, 'node_type': 'IntermediateNode'}
# 900.0 1950
# {'id': 'intermediate_1_19_37613', 'layer_index': 19, 'token_position': 1, 'feature_index': 37613.0, 'activation': 0.0422, 'node_type': 'IntermediateNode'}
# 950.0 1950
# {'id': 'intermediate_2_19_4835', 'layer_index': 19, 'token_position': 2, 'feature_index': 4835.0, 'activation': 0.1113, 'node_type': 'IntermediateNode'}
# 1050.0 1950
# {'id': 'intermediate_2_19_13466', 'layer_index': 19, 'token_position': 2, 'feature_index': 13466.0, 'activation': 0.0586, 'node_type': 'IntermediateNode'}
# 1100.0 1950
# {'id': 'intermediate_2_19_14400', 'layer_index': 19, 'token_position': 2, 'feature_index': 14400.0, 'activation': 0.1602, 'node_type': 'IntermediateNode'}
# 1150.0 1950
# {'id': 'intermediate_2_19_22824', 'layer_index': 19, 'token_position': 2, 'feature_index': 22824.0, 'activation': 0.1123, 'node_type': 'IntermediateNode'}
# 1200.0 1950
# {'id': 'intermediate_2_19_25773', 'layer_index': 19, 'token_position': 2, 'feature_index': 25773.0, 'activation': 0.1162, 'node_type': 'IntermediateNode'}
# 1250.0 1950
# {'id': 'intermediate_2_19_28986', 'layer_index': 19, 'token_position': 2, 'feature_index': 28986.0, 'activation': 0.0913, 'node_type': 'IntermediateNode'}
# 1300.0 1950
# {'id': 'intermediate_2_19_33928', 'layer_index': 19, 'token_position': 2, 'feature_index': 33928.0, 'activation': 0.0649, 'node_type': 'IntermediateNode'}
# 1350.0 1950
# {'id': 'intermediate_2_19_34498', 'layer_index': 19, 'token_position': 2, 'feature_index': 34498.0, 'activation': 0.167, 'node_type': 'IntermediateNode'}
# 1400.0 1950
# {'id': 'intermediate_2_19_35350', 'layer_index': 19, 'token_position': 2, 'feature_index': 35350.0, 'activation': 0.0422, 'node_type': 'IntermediateNode'}
# 1450.0 1950
# {'id': 'intermediate_2_19_38357', 'layer_index': 19, 'token_position': 2, 'feature_index': 38357.0, 'activation': 0.3398, 'node_type': 'IntermediateNode'}
# 1500.0 1950
# {'id': 'intermediate_2_19_44746', 'layer_index': 19, 'token_position': 2, 'feature_index': 44746.0, 'activation': 0.0493, 'node_type': 'IntermediateNode'}
# 1550.0 1950
# {'id': 'intermediate_2_19_45155', 'layer_index': 19, 'token_position': 2, 'feature_index': 45155.0, 'activation': 0.3105, 'node_type': 'IntermediateNode'}
# 1600.0 1950
# {'id': 'intermediate_2_19_45186', 'layer_index': 19, 'token_position': 2, 'feature_index': 45186.0, 'activation': 0.1416, 'node_type': 'IntermediateNode'}
# 1650.0 1950
# {'id': 'intermediate_2_19_49734', 'layer_index': 19, 'token_position': 2, 'feature_index': 49734.0, 'activation': 0.207, 'node_type': 'IntermediateNode'}
# 1700.0 1950
# {'id': 'intermediate_2_19_58680', 'layer_index': 19, 'token_position': 2, 'feature_index': 58680.0, 'activation': 0.124, 'node_type': 'IntermediateNode'}
# 1750.0 1950
# {'id': 'intermediate_2_19_62174', 'layer_index': 19, 'token_position': 2, 'feature_index': 62174.0, 'activation': 0.0508, 'node_type': 'IntermediateNode'}
# 1800.0 1950
# {'id': 'intermediate_2_19_71857', 'layer_index': 19, 'token_position': 2, 'feature_index': 71857.0, 'activation': 0.1045, 'node_type': 'IntermediateNode'}
# 1850.0 1950
# {'id': 'intermediate_3_19_1974', 'layer_index': 19, 'token_position': 3, 'feature_index': 1974.0, 'activation': 0.1157, 'node_type': 'IntermediateNode'}
# 1550.0 1950
# {'id': 'intermediate_3_19_12040', 'layer_index': 19, 'token_position': 3, 'feature_index': 12040.0, 'activation': 0.2891, 'node_type': 'IntermediateNode'}
# 1600.0 1950
# {'id': 'intermediate_3_19_20184', 'layer_index': 19, 'token_position': 3, 'feature_index': 20184.0, 'activation': 0.1465, 'node_type': 'IntermediateNode'}
# 1650.0 1950
# {'id': 'intermediate_3_19_31290', 'layer_index': 19, 'token_position': 3, 'feature_index': 31290.0, 'activation': 0.2051, 'node_type': 'IntermediateNode'}
# 1700.0 1950
# {'id': 'intermediate_3_19_40358', 'layer_index': 19, 'token_position': 3, 'feature_index': 40358.0, 'activation': 0.2119, 'node_type': 'IntermediateNode'}
# 1750.0 1950
# {'id': 'intermediate_3_19_49914', 'layer_index': 19, 'token_position': 3, 'feature_index': 49914.0, 'activation': 0.1641, 'node_type': 'IntermediateNode'}
# 1800.0 1950
# {'id': 'intermediate_3_19_52994', 'layer_index': 19, 'token_position': 3, 'feature_index': 52994.0, 'activation': 0.2715, 'node_type': 'IntermediateNode'}
# 1850.0 1950
# {'id': 'intermediate_3_19_59739', 'layer_index': 19, 'token_position': 3, 'feature_index': 59739.0, 'activation': 0.1934, 'node_type': 'IntermediateNode'}
# 1900.0 1950
# {'id': 'intermediate_13_19_54485', 'layer_index': 19, 'token_position': 13, 'feature_index': 54485.0, 'activation': 0.1133, 'node_type': 'IntermediateNode'}
# 6550.0 1950
# {'id': 'intermediate_3_20_8503', 'layer_index': 20, 'token_position': 3, 'feature_index': 8503.0, 'activation': 0.2412, 'node_type': 'IntermediateNode'}
# 1550.0 2050
# {'id': 'intermediate_3_20_13811', 'layer_index': 20, 'token_position': 3, 'feature_index': 13811.0, 'activation': 0.1992, 'node_type': 'IntermediateNode'}
# 1600.0 2050
# {'id': 'intermediate_3_20_24156', 'layer_index': 20, 'token_position': 3, 'feature_index': 24156.0, 'activation': 0.2344, 'node_type': 'IntermediateNode'}
# 1650.0 2050
# {'id': 'intermediate_3_20_69803', 'layer_index': 20, 'token_position': 3, 'feature_index': 69803.0, 'activation': 0.4082, 'node_type': 'IntermediateNode'}
# 1700.0 2050
# {'id': 'intermediate_13_20_1787', 'layer_index': 20, 'token_position': 13, 'feature_index': 1787.0, 'activation': 0.2129, 'node_type': 'IntermediateNode'}
# 6550.0 2050
# {'id': 'intermediate_13_20_28980', 'layer_index': 20, 'token_position': 13, 'feature_index': 28980.0, 'activation': 0.1436, 'node_type': 'IntermediateNode'}
# 6600.0 2050
# {'id': 'intermediate_13_20_33681', 'layer_index': 20, 'token_position': 13, 'feature_index': 33681.0, 'activation': 0.1143, 'node_type': 'IntermediateNode'}
# 6650.0 2050
# {'id': 'intermediate_13_20_36456', 'layer_index': 20, 'token_position': 13, 'feature_index': 36456.0, 'activation': 0.1572, 'node_type': 'IntermediateNode'}
# 6700.0 2050
# {'id': 'intermediate_0_21_68803', 'layer_index': 21, 'token_position': 0, 'feature_index': 68803.0, 'activation': 0.375, 'node_type': 'IntermediateNode'}
# 50.0 2150
# {'id': 'intermediate_3_21_11142', 'layer_index': 21, 'token_position': 3, 'feature_index': 11142.0, 'activation': 0.1631, 'node_type': 'IntermediateNode'}
# 1550.0 2150
# {'id': 'intermediate_3_21_33964', 'layer_index': 21, 'token_position': 3, 'feature_index': 33964.0, 'activation': 0.2871, 'node_type': 'IntermediateNode'}
# 1600.0 2150
# {'id': 'intermediate_3_21_42667', 'layer_index': 21, 'token_position': 3, 'feature_index': 42667.0, 'activation': 0.208, 'node_type': 'IntermediateNode'}
# 1650.0 2150
# {'id': 'intermediate_3_21_43238', 'layer_index': 21, 'token_position': 3, 'feature_index': 43238.0, 'activation': 0.2812, 'node_type': 'IntermediateNode'}
# 1700.0 2150
# {'id': 'intermediate_3_21_52807', 'layer_index': 21, 'token_position': 3, 'feature_index': 52807.0, 'activation': 0.1768, 'node_type': 'IntermediateNode'}
# 1750.0 2150
# {'id': 'intermediate_3_21_60278', 'layer_index': 21, 'token_position': 3, 'feature_index': 60278.0, 'activation': 0.2734, 'node_type': 'IntermediateNode'}
# 1800.0 2150
# {'id': 'intermediate_3_21_67504', 'layer_index': 21, 'token_position': 3, 'feature_index': 67504.0, 'activation': 0.2197, 'node_type': 'IntermediateNode'}
# 1850.0 2150
# {'id': 'intermediate_13_21_2486', 'layer_index': 21, 'token_position': 13, 'feature_index': 2486.0, 'activation': 0.252, 'node_type': 'IntermediateNode'}
# 6550.0 2150
# {'id': 'intermediate_13_21_70534', 'layer_index': 21, 'token_position': 13, 'feature_index': 70534.0, 'activation': 0.2305, 'node_type': 'IntermediateNode'}
# 6600.0 2150
# {'id': 'intermediate_13_22_59282', 'layer_index': 22, 'token_position': 13, 'feature_index': 59282.0, 'activation': 0.2969, 'node_type': 'IntermediateNode'}
# 6550.0 2250
# {'id': 'intermediate_3_23_3692', 'layer_index': 23, 'token_position': 3, 'feature_index': 3692.0, 'activation': 0.0732, 'node_type': 'IntermediateNode'}
# 2000.0 2350
# {'id': 'intermediate_3_23_9251', 'layer_index': 23, 'token_position': 3, 'feature_index': 9251.0, 'activation': 0.2285, 'node_type': 'IntermediateNode'}
# 2050.0 2350
# {'id': 'intermediate_3_23_11019', 'layer_index': 23, 'token_position': 3, 'feature_index': 11019.0, 'activation': 0.0771, 'node_type': 'IntermediateNode'}
# 2100.0 2350
# {'id': 'intermediate_3_23_31600', 'layer_index': 23, 'token_position': 3, 'feature_index': 31600.0, 'activation': 0.1157, 'node_type': 'IntermediateNode'}
# 2150.0 2350
# {'id': 'intermediate_3_23_36003', 'layer_index': 23, 'token_position': 3, 'feature_index': 36003.0, 'activation': 0.0525, 'node_type': 'IntermediateNode'}
# 2200.0 2350
# {'id': 'intermediate_3_23_37626', 'layer_index': 23, 'token_position': 3, 'feature_index': 37626.0, 'activation': 0.0938, 'node_type': 'IntermediateNode'}
# 2250.0 2350
# {'id': 'intermediate_3_23_42656', 'layer_index': 23, 'token_position': 3, 'feature_index': 42656.0, 'activation': 0.0591, 'node_type': 'IntermediateNode'}
# 2300.0 2350
# {'id': 'intermediate_3_23_45226', 'layer_index': 23, 'token_position': 3, 'feature_index': 45226.0, 'activation': 0.1147, 'node_type': 'IntermediateNode'}
# 2350.0 2350
# {'id': 'intermediate_3_23_48724', 'layer_index': 23, 'token_position': 3, 'feature_index': 48724.0, 'activation': 0.063, 'node_type': 'IntermediateNode'}
# 2400.0 2350
# {'id': 'intermediate_3_23_52909', 'layer_index': 23, 'token_position': 3, 'feature_index': 52909.0, 'activation': 0.2246, 'node_type': 'IntermediateNode'}
# 2450.0 2350
# {'id': 'intermediate_3_23_68769', 'layer_index': 23, 'token_position': 3, 'feature_index': 68769.0, 'activation': 0.1211, 'node_type': 'IntermediateNode'}
# 2500.0 2350
# {'id': 'intermediate_3_23_71422', 'layer_index': 23, 'token_position': 3, 'feature_index': 71422.0, 'activation': 0.0439, 'node_type': 'IntermediateNode'}
# 2550.0 2350
# {'id': 'intermediate_13_24_61084', 'layer_index': 24, 'token_position': 13, 'feature_index': 61084.0, 'activation': 0.3359, 'node_type': 'IntermediateNode'}
# 6550.0 2450
# {'id': 'intermediate_13_26_63797', 'layer_index': 26, 'token_position': 13, 'feature_index': 63797.0, 'activation': 0.5469, 'node_type': 'IntermediateNode'}
# 6550.0 2650
# {'id': 'intermediate_13_29_40650', 'layer_index': 29, 'token_position': 13, 'feature_index': 40650.0, 'activation': 0.2578, 'node_type': 'IntermediateNode'}
# 6550.0 2950
# {'id': 'intermediate_13_29_46192', 'layer_index': 29, 'token_position': 13, 'feature_index': 46192.0, 'activation': 0.0898, 'node_type': 'IntermediateNode'}
# 6600.0 2950
# {'id': 'intermediate_13_29_48752', 'layer_index': 29, 'token_position': 13, 'feature_index': 48752.0, 'activation': 0.3496, 'node_type': 'IntermediateNode'}
# 6650.0 2950
# {'weight': 0.0099}
# {'weight': 0.5859}
# {'weight': 0.0081}
# {'weight': 0.5625}
# {'weight': 0.0089}
# {'weight': 0.6328}
# {'weight': -0.0554}
# {'weight': 0.021}
# {'weight': 0.0211}
# {'weight': 0.0051}
# {'weight': -0.0164}
# {'weight': 0.6562}
# {'weight': 0.4961}
# {'weight': 0.4902}
# {'weight': 0.1641}
# {'weight': 0.0003}
# {'weight': 0.6172}
# {'weight': 0.0006}
# {'weight': 0.0005}
# {'weight': 0.6094}
# {'weight': 0.0004}
# {'weight': 0.001}
# {'weight': 0.0004}
# {'weight': 0.0192}
# {'weight': 0.0113}
# {'weight': 0.0064}
# {'weight': 0.0002}
# {'weight': 0.0002}
# {'weight': 0.0046}
# {'weight': 0.0049}
# {'weight': 0.1021}
# {'weight': 0.1064}
# {'weight': 0.1094}
# {'weight': 0.0034}
# {'weight': 0.0052}
# {'weight': -0.0058}
# {'weight': 0.0038}
# {'weight': -0.0052}
# {'weight': 0.0063}
# {'weight': 0.0037}
# {'weight': 0.0038}
# {'weight': 0.0049}
# {'weight': 0.006}
# {'weight': 0.004}
# {'weight': 0.0041}
# {'weight': 0.009}
# {'weight': 0.0037}
# {'weight': 0.0036}
# {'weight': 0.0034}
# {'weight': 0.0058}
# {'weight': 0.0034}
# {'weight': 0.0033}
# {'weight': 0.0042}
# {'weight': 0.0046}
# {'weight': 0.0002}
# {'weight': 0.0093}
# {'weight': 0.0933}
# {'weight': 0.0005}
# {'weight': 0.4609}
# {'weight': 0.0004}
# {'weight': 0.001}
# {'weight': 0.0003}
# {'weight': 0.0004}
# {'weight': 0.0009}
# {'weight': 0.0003}
# {'weight': 0.0004}
# {'weight': 0.0003}
# {'weight': -0.0003}
# {'weight': 0.0004}
# {'weight': 0.0012}
# {'weight': 0.0004}
# {'weight': 0.0005}
# {'weight': -0.0007}
# {'weight': 0.001}
# {'weight': 0.0004}
# {'weight': 0.0004}
# {'weight': 0.4238}
# {'weight': 0.0003}
# {'weight': 0.0002}
# {'weight': 0.0096}
# {'weight': 0.0006}
# {'weight': -0.002}
# {'weight': 0.0012}
# {'weight': 0.0006}
# {'weight': 0.0006}
# {'weight': 0.0014}
# {'weight': 0.0013}
# {'weight': 0.0006}
# {'weight': 0.0002}
# {'weight': 0.0019}
# {'weight': 0.0006}
# {'weight': 0.0007}
# {'weight': 0.0018}
# {'weight': 0.0008}
# {'weight': 0.0011}
# {'weight': 0.0013}
# {'weight': 0.0008}
# {'weight': 0.0012}
# {'weight': 0.0003}
# {'weight': 0.0009}
# {'weight': 0.032}
# {'weight': 0.0085}
# {'weight': 0.015}
# {'weight': 0.0188}
# {'weight': 0.0004}
# {'weight': 0.0071}
# {'weight': 0.0006}
# {'weight': 0.0113}
# {'weight': 0.0051}
# {'weight': 0.0146}
# {'weight': 0.0063}
# {'weight': 0.0003}
# {'weight': 0.0114}
# {'weight': -0.0178}
# {'weight': 0.0132}
# {'weight': 0.0155}
# {'weight': 0.0074}
# {'weight': 0.0116}
# {'weight': 0.0121}
# {'weight': 0.0104}
# {'weight': 0.0107}
# {'weight': 0.0084}
# {'weight': 0.0114}
# {'weight': -0.0173}
# {'weight': 0.0182}
# {'weight': -0.0114}
# {'weight': 0.0135}
# {'weight': 0.0118}
# {'weight': 0.0091}
# {'weight': 0.0131}
# {'weight': 0.0078}
# {'weight': 0.1855}
# {'weight': 0.0006}
# {'weight': 0.0005}
# {'weight': -0.0021}
# {'weight': 0.0008}
# {'weight': 0.0103}
# {'weight': 0.0156}
# {'weight': 0.0052}
# {'weight': 0.0138}
# {'weight': 0.0106}
# {'weight': 0.0128}
# {'weight': 0.0081}
# {'weight': 0.0071}
# {'weight': 0.0092}
# {'weight': 0.0069}
# {'weight': 0.0173}
# {'weight': 0.0361}
# {'weight': 0.0118}
# {'weight': 0.0122}
# {'weight': -0.0157}
# {'weight': 0.0121}
# {'weight': -0.0131}
# {'weight': 0.0103}
# {'weight': 0.0096}
# {'weight': 0.0087}
# {'weight': 0.007}
# {'weight': 0.0062}
# {'weight': 0.0009}
# {'weight': 0.0017}
# {'weight': 0.0015}
# {'weight': 0.0009}
# {'weight': 0.0032}
# {'weight': -0.0034}
# {'weight': 0.0012}
# {'weight': 0.0014}
# {'weight': 0.0013}
# {'weight': 0.0009}
# {'weight': 0.0008}
# {'weight': 0.0022}
# {'weight': 0.0009}
# {'weight': 0.0022}
# {'weight': 0.0009}
# {'weight': 0.002}
# {'weight': 0.0008}
# {'weight': -0.0027}
# {'weight': 0.0039}
# {'weight': 0.0014}
# {'weight': 0.0018}
# {'weight': 0.0018}
# {'weight': 0.0123}
# {'weight': 0.0081}
# {'weight': 0.0066}
# {'weight': -0.6367}
# {'weight': 0.0003}
# {'weight': 0.0002}
# {'weight': 0.0004}
# {'weight': -0.0009}
# {'weight': 0.0013}
# {'weight': 0.0004}
# {'weight': -0.0009}
# {'weight': 0.0092}
# {'weight': 0.0171}
# {'weight': 0.0096}
# {'weight': -0.0364}
# {'weight': 0.03}
# {'weight': -0.0256}
# {'weight': -0.0425}
# {'weight': 0.0264}
# {'weight': 0.0276}
# {'weight': -0.0156}
# {'weight': 0.0123}
# {'weight': 0.0003}
# {'weight': -0.0131}
# {'weight': 0.0003}
# {'weight': 0.0002}
# {'weight': 0.0003}
# {'weight': 0.0091}
# {'weight': 0.0003}
# {'weight': 0.0003}
# {'weight': 0.006}
# {'weight': 0.0002}
# {'weight': 0.0085}
# {'weight': 0.0002}
# {'weight': 0.0004}
# {'weight': 0.0142}
# {'weight': 0.0003}
# {'weight': 0.006}
# {'weight': 0.0003}
# {'weight': 0.0084}
# {'weight': 0.007}
# {'weight': 0.009}
# {'weight': 0.0075}
# {'weight': -0.0123}
# {'weight': 0.0003}
# {'weight': -0.0005}
# {'weight': 0.0065}
# {'weight': 0.0004}
# {'weight': 0.0044}
# {'weight': 0.0003}
# {'weight': 0.0058}
# {'weight': 0.0058}
# {'weight': 0.0078}
# {'weight': 0.0053}
# {'weight': 0.0078}
# {'weight': 0.0071}
# {'weight': 0.0066}
# {'weight': 0.0002}
# {'weight': 0.0003}
# {'weight': 0.0079}
# {'weight': 0.0003}
# {'weight': 0.0002}
# {'weight': 0.0078}
# {'weight': 0.0069}
# {'weight': 0.0002}
# {'weight': 0.0004}
# {'weight': 0.0002}
# {'weight': 0.0003}
# {'weight': -0.0004}
# {'weight': -0.0005}
# {'weight': -0.0005}
# {'weight': 0.0002}
# {'weight': 0.0164}
# {'weight': 0.0134}
# {'weight': 0.0083}
# {'weight': 0.0205}
# {'weight': -0.0166}
# {'weight': 0.0063}
# {'weight': 0.0149}
# {'weight': 0.0183}
# {'weight': 0.0071}
# {'weight': 0.006}
# {'weight': 0.0086}
# {'weight': 0.006}
# {'weight': 0.0065}
# {'weight': 0.0092}
# {'weight': 0.0327}
# {'weight': -0.0284}
# {'weight': -0.0454}
# {'weight': 0.0378}
# {'weight': 0.025}
# {'weight': 0.0082}
# {'weight': 0.0049}
# {'weight': 0.0176}
# {'weight': 0.0165}
# {'weight': -0.0219}
# {'weight': 0.0056}
# {'weight': 0.0118}
# {'weight': 0.0155}
# {'weight': 0.0117}
# {'weight': 0.0354}
# {'weight': 0.0061}
# {'weight': 0.0072}
# {'weight': 0.0121}
# {'weight': 0.0072}
# {'weight': 0.0076}
# {'weight': 0.0053}
# {'weight': 0.0095}
# {'weight': 0.0072}
# {'weight': 0.0049}
# {'weight': 0.0089}
# {'weight': 0.0002}
# {'weight': 0.0068}
# {'weight': 0.0002}
# {'weight': 0.005}
# {'weight': 0.005}
# {'weight': 0.004}
# {'weight': 0.0002}
# {'weight': 0.0056}
# {'weight': 0.0004}
# {'weight': 0.0005}
# {'weight': 0.0003}
# {'weight': 0.0004}
# {'weight': 0.0008}
# {'weight': 0.0004}
# {'weight': 0.0005}
# {'weight': 0.0004}
# {'weight': 0.0004}
# {'weight': 0.0003}
# {'weight': 0.0135}
# {'weight': 0.0057}
# {'weight': 0.0047}
# {'weight': 0.01}
# {'weight': 0.0044}
# {'weight': -0.0103}
# {'weight': 0.005}
# {'weight': 0.0044}
# {'weight': 0.004}
# {'weight': -0.0125}
# {'weight': 0.0102}
# {'weight': 0.0155}
# {'weight': 0.0063}
# {'weight': 0.0064}
# {'weight': 0.0044}
# {'weight': 0.0042}
# {'weight': 0.0053}
# {'weight': 0.0074}
# {'weight': 0.0205}
# {'weight': 0.0095}
# {'weight': 0.0049}
# {'weight': 0.0084}
# {'weight': 0.0105}
# {'weight': 0.0229}
# {'weight': 0.0119}
# {'weight': 0.0129}
# {'weight': 0.0168}
# {'weight': 0.0073}
# {'weight': 0.0053}
# {'weight': 0.1309}
# {'weight': 0.0211}
# {'weight': 0.0251}
# {'weight': 0.0197}
# {'weight': 0.0084}
# {'weight': 0.0096}
# {'weight': 0.009}
# {'weight': 0.0194}
# {'weight': 0.0173}
# {'weight': 0.0165}
# {'weight': 0.0271}
# {'weight': 0.0349}
# {'weight': 0.0283}
# {'weight': -0.0204}
# {'weight': 0.126}
# {'weight': 0.0977}
# {'weight': 0.1011}
# {'weight': 0.1357}
# {'weight': 0.0006}
# {'weight': 0.0096}
# {'weight': 0.0063}
# {'weight': 0.0086}
# {'weight': 0.0074}
# {'weight': 0.0079}
# {'weight': 0.0176}
# {'weight': 0.0076}
# {'weight': 0.0067}
# {'weight': 0.0197}
# {'weight': 0.0069}
# {'weight': 0.014}
# {'weight': 0.0083}
# {'weight': 0.1216}
# {'weight': 0.1562}
# {'weight': 0.1289}
# {'weight': 0.4102}
# {'weight': 0.4512}
# {'weight': -0.4238}
# {'weight': -0.457}
# {'weight': 0.4375}
# {'weight': 0.4609}
# {'weight': 0.4473}
# {'weight': 0.4512}
# {'weight': 0.4004}
# {'weight': 0.4277}
# {'weight': 0.4316}
# {'weight': 0.4336}
# {'weight': 0.1035}
# {'weight': -0.7266}
# {'weight': 0.0996}
# {'weight': 0.0947}
# {'weight': 0.1631}

# %%
nt.show('attribution_graph_visualization.html')
# Out:
# attribution_graph_visualization.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="attribution_graph_visualization.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
nt.from_nx(G)
